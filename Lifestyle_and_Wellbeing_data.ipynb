# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams['font.size'] = 10

# %%
life = pd.read_csv('Wellbeing_and_lifestyle_data_Kaggle.csv')

# %%
life.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15972 entries, 0 to 15971
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Timestamp                15972 non-null  object
#  1   FRUITS_VEGGIES           15972 non-null  int64
#  2   DAILY_STRESS             15972 non-null  object
#  3   PLACES_VISITED           15972 non-null  int64
#  4   CORE_CIRCLE              15972 non-null  int64
#  5   SUPPORTING_OTHERS        15972 non-null  int64
#  6   SOCIAL_NETWORK           15972 non-null  int64
#  7   ACHIEVEMENT              15972 non-null  int64
#  8   DONATION                 15972 non-null  int64
#  9   BMI_RANGE                15972 non-null  int64
#  10  TODO_COMPLETED           15972 non-null  int64
#  11  FLOW                     15972 non-null  int64
#  12  DAILY_STEPS              15972 non-null  int64
#  13  LIVE_VISION              15972 non-null  int64
# ...

# %%
life.describe()
# Out:
#        FRUITS_VEGGIES  PLACES_VISITED   CORE_CIRCLE  SUPPORTING_OTHERS  \
# count    15972.000000    15972.000000  15972.000000       15972.000000
# mean         2.922677        5.232970      5.508077           5.616454
# std          1.442694        3.311912      2.840334           3.242021
# min          0.000000        0.000000      0.000000           0.000000
# 25%          2.000000        2.000000      3.000000           3.000000
# 50%          3.000000        5.000000      5.000000           5.000000
# 75%          4.000000        8.000000      8.000000          10.000000
# max          5.000000       10.000000     10.000000          10.000000
#
#        SOCIAL_NETWORK   ACHIEVEMENT      DONATION     BMI_RANGE  \
# count    15972.000000  15972.000000  15972.000000  15972.000000
# mean         6.474267      4.000751      2.715314      1.410656
# std          3.086672      2.755837      1.851586      0.491968
# min          0.000000      0.000000      0.000000      1.000000
# ...

# %%
life.head(15972)
# Out:
#           Timestamp  FRUITS_VEGGIES DAILY_STRESS  PLACES_VISITED  CORE_CIRCLE  \
# 0            7/7/15               3            2               2            5
# 1            7/7/15               2            3               4            3
# 2            7/7/15               2            3               3            4
# 3            7/7/15               3            3              10            3
# 4            7/7/15               5            1               3            3
# ...             ...             ...          ...             ...          ...
# 15967  3/14/21 5:42               3            3               0            4
# 15968  3/14/21 6:30               3            3               6            8
# 15969  3/14/21 8:35               4            3               0           10
# 15970  3/14/21 8:43               1            1              10            8
# 15971  3/14/21 9:03               5            4               0            2
#
# ...

# %%
life["FRUITS_VEGGIES"].plot(kind="hist", bins=30, colormap='plasma')
# Out:
# <Axes: ylabel='Frequency'>

# %%
life['WORK_LIFE_BALANCE_SCORE'].plot(kind='hist', bins=30, colormap='plasma')
plt.ylabel('Frequency')
plt.xlabel('Work-Life Balance Score')
plt.title('Work-Life Balance (happiness) Distribution')
plt.grid()
plt.show()

# %%
newLife = life.drop(['Timestamp', 'FLOW', 'DAILY_SHOUTING', 'LOST_VACATION'], axis = 1)

# %%
newLife.info()
newLife.head(15972)
newLife.sort_values('WORK_LIFE_BALANCE_SCORE', ascending=False).head(15972)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15972 entries, 0 to 15971
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   FRUITS_VEGGIES           15972 non-null  int64
#  1   DAILY_STRESS             15972 non-null  object
#  2   PLACES_VISITED           15972 non-null  int64
#  3   CORE_CIRCLE              15972 non-null  int64
#  4   SUPPORTING_OTHERS        15972 non-null  int64
#  5   SOCIAL_NETWORK           15972 non-null  int64
#  6   ACHIEVEMENT              15972 non-null  int64
#  7   DONATION                 15972 non-null  int64
#  8   BMI_RANGE                15972 non-null  int64
#  9   TODO_COMPLETED           15972 non-null  int64
#  10  DAILY_STEPS              15972 non-null  int64
#  11  LIVE_VISION              15972 non-null  int64
#  12  SLEEP_HOURS              15972 non-null  int64
#  13  SUFFICIENT_INCOME        15972 non-null  int64
# ...

# %%
#Storing top 1000 on the basis of work_balance( doing meditation)

# %%
topthousand = newLife[['FRUITS_VEGGIES', 'DAILY_STRESS', 'PLACES_VISITED', 'CORE_CIRCLE',
       'SUPPORTING_OTHERS', 'SOCIAL_NETWORK', 'ACHIEVEMENT', 'DONATION',
       'BMI_RANGE', 'TODO_COMPLETED', 'DAILY_STEPS', 'LIVE_VISION',
       'SLEEP_HOURS', 'SUFFICIENT_INCOME', 'PERSONAL_AWARDS',
       'TIME_FOR_PASSION', 'WEEKLY_MEDITATION', 'AGE', 'GENDER',
       'WORK_LIFE_BALANCE_SCORE']].sort_values('WORK_LIFE_BALANCE_SCORE', ascending=False).head(1000)

# %%
# top1000 on the basis of ages

# %%
topthousand['AGE'].value_counts().plot(kind='pie', colormap='plasma')
topthousand['AGE'].value_counts()
# Out:
# 51 or more      347
# 36 to 50        316
# 21 to 35        251
# Less than 20     86
# Name: AGE, dtype: int64

# %%
# top1000 basis of Gender

# %%
topthousand['GENDER'].value_counts().plot(kind='pie', colormap='plasma')
topthousand['GENDER'].value_counts()
# Out:
# Female    598
# Male      402
# Name: GENDER, dtype: int64

# %%
#bot 1000 on the basis of worl_balance( not doing meditation)

# %%
botthousand = newLife[['FRUITS_VEGGIES', 'DAILY_STRESS', 'PLACES_VISITED', 'CORE_CIRCLE',
       'SUPPORTING_OTHERS', 'SOCIAL_NETWORK', 'ACHIEVEMENT', 'DONATION',
       'BMI_RANGE', 'TODO_COMPLETED', 'DAILY_STEPS', 'LIVE_VISION',
       'SLEEP_HOURS', 'SUFFICIENT_INCOME', 'PERSONAL_AWARDS',
       'TIME_FOR_PASSION', 'WEEKLY_MEDITATION', 'AGE', 'GENDER',
       'WORK_LIFE_BALANCE_SCORE']].sort_values('WORK_LIFE_BALANCE_SCORE', ascending=True).head(1000)

# %%
# bot 1000 on the basis of age

# %%
botthousand['AGE'].value_counts().plot(kind='pie', colormap='plasma')
botthousand['AGE'].value_counts()
# Out:
# 21 to 35        464
# 36 to 50        284
# 51 or more      134
# Less than 20    118
# Name: AGE, dtype: int64

# %%
# bot 1000 on the basis of gender

# %%
botthousand['GENDER'].value_counts().plot(kind='pie', colormap='plasma')
botthousand['GENDER'].value_counts()
# Out:
# Female    574
# Male      426
# Name: GENDER, dtype: int64

# %%
# top 1000 on the basis of stress( 1 = low stress and 5= high stress)

# %%
topthousand['DAILY_STRESS'].value_counts().plot(kind='pie', colormap='plasma')
topthousand['DAILY_STRESS'].value_counts()
# Out:
# 1    312
# 2    250
# 3    190
# 0    147
# 4     73
# 5     28
# Name: DAILY_STRESS, dtype: int64

# %%
# bottom 1000 on basis of stress ( 1= low stress and 5 = high_stress)

# %%
botthousand['DAILY_STRESS'].value_counts().plot(kind='pie', colormap='plasma')
botthousand['DAILY_STRESS'].value_counts()
# Out:
# 5    386
# 4    262
# 3    195
# 2    105
# 1     38
# 0     14
# Name: DAILY_STRESS, dtype: int64

# %%
# findinf top and bottom 1000 mean values for the 20 columns

# %%
topMean = topthousand[['FRUITS_VEGGIES', 'DAILY_STRESS', 'PLACES_VISITED', 'CORE_CIRCLE',
       'SUPPORTING_OTHERS', 'SOCIAL_NETWORK', 'ACHIEVEMENT', 'DONATION', 'TODO_COMPLETED', 'DAILY_STEPS', 'LIVE_VISION',
       'SLEEP_HOURS', 'SUFFICIENT_INCOME', 'PERSONAL_AWARDS',
       'TIME_FOR_PASSION', 'WEEKLY_MEDITATION',
       'WORK_LIFE_BALANCE_SCORE']].mean()
botMean = botthousand[['FRUITS_VEGGIES', 'DAILY_STRESS', 'PLACES_VISITED', 'CORE_CIRCLE',
       'SUPPORTING_OTHERS', 'SOCIAL_NETWORK', 'ACHIEVEMENT', 'DONATION', 'TODO_COMPLETED', 'DAILY_STEPS', 'LIVE_VISION',
       'SLEEP_HOURS', 'SUFFICIENT_INCOME', 'PERSONAL_AWARDS',
       'TIME_FOR_PASSION', 'WEEKLY_MEDITATION',
       'WORK_LIFE_BALANCE_SCORE']].mean()
categories = ['FRUITS_VEGGIES', 'PLACES_VISITED', 'CORE_CIRCLE',
       'SUPPORTING_OTHERS', 'SOCIAL_NETWORK', 'ACHIEVEMENT', 'DONATION', 'TODO_COMPLETED', 'DAILY_STEPS', 'LIVE_VISION',
       'SLEEP_HOURS', 'SUFFICIENT_INCOME', 'PERSONAL_AWARDS',
       'TIME_FOR_PASSION', 'WEEKLY_MEDITATION']

# %%
print(topMean)
# Out:
# FRUITS_VEGGIES               4.1060
# DAILY_STRESS                    inf
# PLACES_VISITED               8.3660
# CORE_CIRCLE                  8.1860
# SUPPORTING_OTHERS            9.0530
# SOCIAL_NETWORK               8.6720
# ACHIEVEMENT                  7.4610
# DONATION                     4.3280
# TODO_COMPLETED               8.0960
# DAILY_STEPS                  8.0610
# LIVE_VISION                  7.1040
# SLEEP_HOURS                  7.4310
# SUFFICIENT_INCOME            1.9590
# PERSONAL_AWARDS              8.7600
# TIME_FOR_PASSION             6.6690
# WEEKLY_MEDITATION            8.7380
# WORK_LIFE_BALANCE_SCORE    751.7625
# dtype: float64

# %%
print(botMean)
# Out:
# FRUITS_VEGGIES               1.558
# DAILY_STRESS                   inf
# PLACES_VISITED               1.737
# CORE_CIRCLE                  2.791
# SUPPORTING_OTHERS            2.366
# SOCIAL_NETWORK               3.808
# ACHIEVEMENT                  1.357
# DONATION                     1.049
# TODO_COMPLETED               2.676
# DAILY_STEPS                  3.194
# LIVE_VISION                  1.202
# SLEEP_HOURS                  6.503
# SUFFICIENT_INCOME            1.271
# PERSONAL_AWARDS              2.892
# TIME_FOR_PASSION             1.096
# WEEKLY_MEDITATION            3.798
# WORK_LIFE_BALANCE_SCORE    577.382
# dtype: float64

# %%
# making a bar graph for comparing top and bottom peoples

# %%
topMeanVal = [4.1060, 8.3660, 8.1860, 9.0530, 8.6720, 7.4610, 4.3280, 8.0960, 8.0610, 7.1040, 7.4310, 1.9590, 8.7600, 6.6690, 8.7380]

botMeanVal = [1.558, 1.737, 2.791, 2.366, 3.808, 1.357, 1.049, 2.676, 3.194, 1.202, 6.503, 1.271, 2.892, 1.096, 3.798]

# %%
labels = ['FRUITS_VEGGIES', 'PLACES_VISITED', 'CORE_CIRCLE', 'SUPPORTING_OTHERS', 'SOCIAL_NETWORK', 
          'ACHIEVEMENT', 'DONATION', 'TODO_COMPLETED', 'DAILY_STEPS', 'LIVE_VISION',
          'SLEEP_HOURS', 'SUFFICIENT_INCOME', 'PERSONAL_AWARDS','TIME_FOR_PASSION', 'WEEKLY_MEDITATION']

topMeans = [4.1060, 8.3660, 8.1860, 9.0530, 8.6720, 7.4610, 4.3280, 8.0960, 8.0610, 7.1040, 7.4310, 1.9590, 8.7600, 6.6690, 8.7380]
botMeans = [1.558, 1.737, 2.791, 2.366, 3.808, 1.357, 1.049, 2.676, 3.194, 1.202, 6.503, 1.271, 2.892, 1.096, 3.798] 

df = pd.DataFrame({'botMeans1': botMeans,
                   'topMeans1': topMeans}, index = labels)

ax = df.plot.bar(rot=0)

plt.legend()
plt.title('Average scores per question for the top and bottom 1000 individuals')
# Out:
# Text(0.5, 1.0, 'Average scores per question for the top and bottom 1000 individuals')

# %%
# taking the peoples from 21 to 35 and doing analysis

# %%
youngGroup = newLife.loc[newLife['AGE'] == '21 to 35']
youngGroup
# Out:
#        FRUITS_VEGGIES DAILY_STRESS  PLACES_VISITED  CORE_CIRCLE  \
# 7                   3            4               5            3
# 8                   5            3               6            4
# 11                  1            4               3            8
# 12                  2            2              10            5
# 14                  3            3               2            3
# ...               ...          ...             ...          ...
# 15965               5            4               2            4
# 15968               3            3               6            8
# 15969               4            3               0           10
# 15970               1            1              10            8
# 15971               5            4               0            2
#
#        SUPPORTING_OTHERS  SOCIAL_NETWORK  ACHIEVEMENT  DONATION  BMI_RANGE  \
# 7                      5               7            4         0          1
# ...

# %%
#gender in 21 to 35 age

# %%
youngGroup['GENDER'].value_counts().plot(kind='pie', colormap='plasma')
youngGroup['GENDER'].value_counts()
# Out:
# Female    3541
# Male      2567
# Name: GENDER, dtype: int64

# %%
# taking young groups from top mean scores and storing having life_balance>732

# %%
youngHigh = youngGroup.loc[youngGroup['WORK_LIFE_BALANCE_SCORE'] >= 732.1 ]
youngHigh
# Out:
#        FRUITS_VEGGIES DAILY_STRESS  PLACES_VISITED  CORE_CIRCLE  \
# 34                  4            2              10            6
# 70                  4            3              10           10
# 92                  5            3               8            1
# 202                 2            1              10            8
# 214                 3            1               5            9
# ...               ...          ...             ...          ...
# 15765               5            0              10            5
# 15771               3            2               5           10
# 15804               5            3              10           10
# 15898               4            3               8            8
# 15918               4            3              10           10
#
#        SUPPORTING_OTHERS  SOCIAL_NETWORK  ACHIEVEMENT  DONATION  BMI_RANGE  \
# 34                    10               8           10         2          1
# ...

# %%
young_High_Mean = youngHigh[['FRUITS_VEGGIES', 'PLACES_VISITED', 'CORE_CIRCLE',
       'SUPPORTING_OTHERS', 'SOCIAL_NETWORK', 'ACHIEVEMENT', 'DONATION', 'TODO_COMPLETED', 'DAILY_STEPS', 'LIVE_VISION',
       'SLEEP_HOURS', 'SUFFICIENT_INCOME', 'PERSONAL_AWARDS',
       'TIME_FOR_PASSION', 'WEEKLY_MEDITATION']].mean()

young_High_Mean
# Out:
# FRUITS_VEGGIES       4.003367
# PLACES_VISITED       8.727273
# CORE_CIRCLE          8.175084
# SUPPORTING_OTHERS    8.939394
# SOCIAL_NETWORK       8.700337
# ACHIEVEMENT          7.185185
# DONATION             3.989899
# TODO_COMPLETED       7.814815
# DAILY_STEPS          8.249158
# LIVE_VISION          6.511785
# SLEEP_HOURS          7.454545
# SUFFICIENT_INCOME    1.929293
# PERSONAL_AWARDS      8.471380
# TIME_FOR_PASSION     6.767677
# WEEKLY_MEDITATION    8.572391
# dtype: float64

# %%
labels = ['FRUITS_VEGGIES', 'PLACES_VISITED', 'CORE_CIRCLE',
       'SUPPORTING_OTHERS', 'SOCIAL_NETWORK', 'ACHIEVEMENT', 'DONATION', 'TODO_COMPLETED', 'DAILY_STEPS', 'LIVE_VISION',
       'SLEEP_HOURS', 'SUFFICIENT_INCOME', 'PERSONAL_AWARDS',
       'TIME_FOR_PASSION', 'WEEKLY_MEDITATION']
young_High_Means =[4.003, 8.7272, 8.1750, 8.9393, 8.7003, 7.1851, 3.9898, 7.8148, 8.2491, 6.5117, 7.4545, 1.9292, 8.4713, 6.7676, 8.5723]
topMeans = [4.1060, 8.3660, 8.1860, 9.0530, 8.6720, 7.4610, 4.3280, 8.0960, 8.0610, 7.1040, 7.4310, 1.9590, 8.7600, 6.6690, 8.7380]

df1 = pd.DataFrame({'youngMeans1': young_High_Means,
                   'topMeans1': topMeans}, index = labels)

ax = df1.plot.bar(rot=0)

# %%
#social network, core circle and helping others in all ages categories (under 20, 21-35, 36-50)

# %%
newLife.columns
socialVars = newLife.drop(['FRUITS_VEGGIES', 'DAILY_STRESS', 'PLACES_VISITED','ACHIEVEMENT', 'DONATION',
       'BMI_RANGE', 'TODO_COMPLETED', 'DAILY_STEPS', 'LIVE_VISION',
       'SLEEP_HOURS', 'SUFFICIENT_INCOME', 'PERSONAL_AWARDS',
       'TIME_FOR_PASSION', 'WEEKLY_MEDITATION'], axis = 1)

# %%
socialVars.columns
# Out:
# Index(['CORE_CIRCLE', 'SUPPORTING_OTHERS', 'SOCIAL_NETWORK', 'AGE', 'GENDER',
#        'WORK_LIFE_BALANCE_SCORE'],
#       dtype='object')

# %%
socialVars1 = socialVars.loc[newLife['AGE'] == 'Less than 20']
socialVars2 = socialVars.loc[newLife['AGE'] == '21 to 35']
socialVars3 = socialVars.loc[newLife['AGE'] == '36 to 50']
socialVars4 = socialVars.loc[newLife['AGE'] == '51 or more ']

sv1Mean = socialVars1[['CORE_CIRCLE', 'SUPPORTING_OTHERS', 'SOCIAL_NETWORK']].mean()
sv2Mean = socialVars2[['CORE_CIRCLE', 'SUPPORTING_OTHERS', 'SOCIAL_NETWORK']].mean()
sv3Mean = socialVars3[['CORE_CIRCLE', 'SUPPORTING_OTHERS', 'SOCIAL_NETWORK']].mean()
sv4Mean = socialVars4[['CORE_CIRCLE', 'SUPPORTING_OTHERS', 'SOCIAL_NETWORK']].mean()

# %%
plt.figure(figsize=(10,6))
plt.plot(sv1Mean, "o:r")
plt.plot(sv2Mean, "o:y")
plt.plot(sv3Mean, "o:b")
plt.show()
